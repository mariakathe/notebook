# %% [markdown]
# # Gettin data from a NOAA webpage

# %%
# !wget -O land_global_temperature_anomaly_1880_2015.csv https://www.ncdc.noaa.gov/cag/time-series/global/globe/land/all/1/1880-2015.csv
# Out:
# --2017-01-04 13:27:53--  https://www.ncdc.noaa.gov/cag/time-series/global/globe/land/all/1/1880-2015.csv
# Resolviendo www.ncdc.noaa.gov (www.ncdc.noaa.gov)... 205.167.25.171, 205.167.25.172, 2610:20:8040:2::171, ...
# Conectando con www.ncdc.noaa.gov (www.ncdc.noaa.gov)[205.167.25.171]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: no especificado [text/plain]
# Grabando a: “land_global_temperature_anomaly_1880_2015.csv”
#
#     [ <=>                                   ] 23.796       134KB/s   en 0,2s
#
# 2017-01-04 13:27:54 (134 KB/s) - “land_global_temperature_anomaly_1880_2015.csv” guardado [23796]

# %%
import numpy

# %%
# !head land_global_temperature_anomaly_1880_2015.csv
# Out:
# Global Land Temperature Anomalies
# Units: Degrees Celsius
# Base Period: 1901-2000
# Year,Value
# 188001,-0.1538
# 188002,-0.5771
# 188003,-0.7250
# 188004,-0.2990
# 188005,-0.2098
# 188006,-0.3002

# %%
numpy.loadtxt(fname='land_global_temperature_anomaly_1880_2015.csv', delimiter=',', skiprows=4)
# Out:
# array([[  1.88001000e+05,  -1.53800000e-01],
#        [  1.88002000e+05,  -5.77100000e-01],
#        [  1.88003000e+05,  -7.25000000e-01],
#        ...,
#        [  2.01510000e+05,   1.32120000e+00],
#        [  2.01511000e+05,   1.28280000e+00],
#        [  2.01512000e+05,   1.87220000e+00]])

# %%
T_land = numpy.loadtxt(fname='land_global_temperature_anomaly_1880_2015.csv', delimiter=',', skiprows=4)

# %%
print(T_land)
# Out:
# [[  1.88001000e+05  -1.53800000e-01]
#  [  1.88002000e+05  -5.77100000e-01]
#  [  1.88003000e+05  -7.25000000e-01]
#  ...,
#  [  2.01510000e+05   1.32120000e+00]
#  [  2.01511000e+05   1.28280000e+00]
#  [  2.01512000e+05   1.87220000e+00]]

# %%
numpy.shape(T_land)
# Out:
# (1632, 2)

# %%
T_land.shape
# Out:
# (1632, 2)

# %%
1632/12
# Out:
# 136.0

# %%
from matplotlib import pyplot
# %matplotlib inline

# %%
T_land[0]
# Out:
# array([  1.88001000e+05,  -1.53800000e-01])

# %%
T_land[:,1]
# Out:
# array([-0.1538, -0.5771, -0.725 , ...,  1.3212,  1.2828,  1.8722])

# %%
pyplot.plot(T_land[:,1])

# %%
#Remember that to remove the ugly line at the beggining of the plot 
#we use a ; at the end of the command
pyplot.plot(T_land[:,1]);

# %%
pyplot.plot(T_land[:,0], T_land[:,1]);

# %%
pyplot.plot(T_land[0:25,0], T_land[0:25,1]);

# %% [markdown]
# # Using `numpy.arange()` for creating our date-array

# %%
date = numpy.arange('1880', '2016', dtype=('datetime64[M]'))

# %%
print(date)
# Out:
# ['1880-01' '1880-02' '1880-03' ..., '2015-10' '2015-11' '2015-12']

# %%
len(date)
# Out:
# 1632

# %%
dummy = numpy.linspace(1,1632, 1632)

# %%
print(dummy)
# Out:
# [  1.00000000e+00   2.00000000e+00   3.00000000e+00 ...,   1.63000000e+03
#    1.63100000e+03   1.63200000e+03]

# %%
pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, T_land[:, 1]);

# %%
pyplot.xticks(dummy, date, rotation=75)
pyplot.plot(dummy, T_land[:, 1]);

# %%
pyplot.xticks(dummy[1::12*10], date[1::12*10], rotation=75)
pyplot.plot(dummy, T_land[:, 1]);

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16

# %%
pyplot.figure(figsize=(10,5))
pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, T_land[:, 1], color='#2929a3', ls='-', lw=1)
pyplot.title('Land global temperature anomalies. \n')
pyplot.xlabel('Year-Month')
pyplot.ylabel('Land temperature anomaly [ºC]')
pyplot.grid();
#pyplot.savefig('temp_anomalies.pdf');

# %% [markdown]
# # Histograms

# %%
pyplot.figure(figsize=(10,5))
pyplot.hist(T_land[:,1])
pyplot.xlabel('Land temperature anomaly [ºC]')
pyplot.ylabel('Frecuency');

# %%
pyplot.figure(figsize=(10,5))
pyplot.hist(T_land[:,1], bins=25, normed=True, color='g', alpha=0.5)
pyplot.xlabel('Land temperature anomaly [ºC]')
pyplot.ylabel('Normalized frecuency');

# %% [markdown]
# # Let's do some stats

# %%
mean_T = numpy.mean(T_land[:,1])
median_T = numpy.median(T_land[:,1])

print('The mean value is {:.7} and the median is {:.5}'.format(mean_T, median_T))
# Out:
# The mean value is 0.04030993 and the median is -0.0276

# %%
variance_T = numpy.var(T_land[:,1])
sigma_T = numpy.sqrt(variance_T)

print('The variance is {:.5} and the standard deviation is {:.5}'.format(variance_T, sigma_T))
# Out:
# The variance is 0.28041 and the standard deviation is 0.52954

# %%
from scipy import stats

# %%
bins = numpy.linspace(min(T_land[:,1]), max(T_land[:,1]), 40)

pyplot.figure(figsize=(10,5))

#Plot the histogram
pyplot.hist(T_land[:,1], bins, normed=True, color='g', alpha=0.5)

#Plot the probability density function
pyplot.plot(bins, stats.norm.pdf(bins, mean_T, sigma_T), color='#ff5733', ls='-', lw=2.5)

pyplot.xlabel('Land temperature anomaly [ºC]')
pyplot.ylabel('Normalized frecuency')
pyplot.grid();

# %% [markdown]
# # Two plots in the same figure

# %%
pyplot.figure(figsize=(12,4))

#First plot
pyplot.subplot(121) #creates a grid of 1 row, 2 columns and select the first plot

pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, T_land[:, 1], color='#2929a3', ls='-', lw=1)
#pyplot.title('Land global temperature anomalies. \n')
pyplot.xlabel('Year-Month')
pyplot.ylabel('Land temperature anomaly [ºC]')
pyplot.grid()

#Second plot
pyplot.subplot(122)

bins = numpy.linspace(min(T_land[:,1]), max(T_land[:,1]), 40)

#Plot the histogram
pyplot.hist(T_land[:,1], bins, normed=True, color='#2929a3', alpha=0.5, histtype='stepfilled')

#Plot the probability density function
pyplot.plot(bins, stats.norm.pdf(bins, mean_T, sigma_T), color='#ff5733', ls='-', lw=2.5)

pyplot.xlabel('Land temperature anomaly [ºC]')
pyplot.ylabel('Normalized frecuency')
pyplot.grid();

# %% [markdown]
# # Smooth the data

# %%
def smooth_data(N, data):
    """
    Returns smoothed data using a sliging_moving acarage.
    
    Arguments:
    ----------
    N (int)      : amount of data values we want to average.
    data (array) : array of data we want to smooth.
    
    Returns:
    --------
    smooth (array): array with smoothed data.
    """
    
    window = numpy.ones(N)/N
    smooth = numpy.convolve(data, window, 'same')
    
    return smooth

# %%
# ?smooth_data

# %%
smooth = smooth_data(12, T_land[:,1])

# %%
pyplot.figure(figsize=(10,5))

pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, smooth, color='r', ls='-', lw=2)
pyplot.xlabel('Year-Month')
pyplot.ylabel('Land temperature anomaly [ºC]')
pyplot.title('Smooth data')
pyplot.grid();

# %%
pyplot.figure(figsize=(10,5))

pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, T_land[:,1], color='#2929a3', ls='-', lw=1, alpha=0.5)
pyplot.plot(dummy, smooth, color='r', ls='-', lw=2)

pyplot.xlabel('Year-Month')
pyplot.ylabel('Land temperature anomaly [ºC]')
pyplot.title('Data and smooth data')
pyplot.grid();

# %% [markdown]
# # Linear regression (The easy way)

# %%
m, b = numpy.polyfit(dummy, T_land[:,1], 1)

# %%
print(m, b)
# Out:
# 0.000832212749511 -0.639191783505

# %%
f_linear = numpy.poly1d((m,b))

# %%
print(f_linear)
# Out:
#
# 0.0008322 x - 0.6392

# %%
pyplot.figure(figsize=(10,5))

pyplot.xticks(dummy[::12*10], date[::12*10], rotation=75)
pyplot.plot(dummy, T_land[:,1], color='#2929a3', ls='-', lw=1, alpha=0.5)
#Linear regression
pyplot.plot(dummy, f_linear(dummy), color = 'k', ls='--', lw=2, label='linear regression')
#pyplot.plot(dummy, smooth, color='r', ls='-', lw=2)

pyplot.xlabel('Year-Month')
pyplot.ylabel('Land temperature anomaly [ºC]')
pyplot.legend(loc='best', fontsize=15) #loc: location, python elige la mejor loc

pyplot.grid();
